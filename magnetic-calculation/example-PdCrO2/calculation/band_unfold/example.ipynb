# %%
# NotImplemented
M = [[ 2 , 1 , 0 ],
     [ 1 , 2 , 0 ],
     [ 0 , 0 , 2 ]]

# %%
# NotImplemented
high_symmetry_points = [
    [0,0,0], # G
    [0.333,0.333,0], # K
    [0.5,0,0], # K
    [0,0,0], # G
]

# %%
n_kpoints_each_path = 30

# %%
from vaspvis.utils import generate_kpoints

generate_kpoints(
    M=M, # M can be generated with the convert slab function
    high_symmetry_points=high_symmetry_points, # Special points
    n=n_kpoints_each_path, # Number of segments between each special point  # NotImplemented
    output="KPOINTS"  # NotImplemented
)
# Out:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pyvista/utilities/__init__.py:72: PyVistaDeprecationWarning: The `pyvista.utilities` module has been deprecated. `NORMALS` is now imported as: `from pyvista.core.utilities import NORMALS`.
#   warnings.warn(
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pyvista/utilities/__init__.py:72: PyVistaDeprecationWarning: The `pyvista.utilities` module has been deprecated. `generate_plane` is now imported as: `from pyvista.core.utilities import generate_plane`.
#   warnings.warn(
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pyvista/utilities/__init__.py:72: PyVistaDeprecationWarning: The `pyvista.utilities` module has been deprecated. `get_array` is now imported as: `from pyvista.core.utilities import get_array`.
#   warnings.warn(
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pyvista/utilities/__init__.py:72: PyVistaDeprecationWarning: The `pyvista.utilities` module has been deprecated. `try_callback` is now imported as: `from pyvista.core.utilities import try_callback`.
#   warnings.warn(

# %% [markdown]
# Use this KPOINTS file to do NSCF

# %%
from vaspvis import standard as st

# %%
fig, ax = st.band_plain(
    folder= '/global/cfs/cdirs/m3578/chenbo/PdCrO2_calculation/band_unfold',  # NotImplemented
    figsize=(2.5,2),
    save=False,
    erange=[-4,3],
    color='red',
    unfold=True,
    kpath = [
    [r'\Gamma', r'K'],   # Γ → K
    [r'K',      r'M'],   # K → M
    [r'M',      r'\Gamma']  # M → Γ
],  # NotImplemented 3 slices
    high_symm_points=high_symmetry_points,
    n=n_kpoints_each_path,
    M=M,
    # output=os.path.join(band_folder, 'band_plain.png'),
    # scale_factor=5,
    interpolate=True
)
# Out:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:276: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:798: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:1365: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:

# %%
fig, ax = st.band_element_spd(
    folder= '/global/cfs/cdirs/m3578/chenbo/PdCrO2_calculation/band_unfold',  
    figsize=(4,2),
    save=False,
    erange=[-4,3],
    element_spd_dict={'Pd': 'd', 'Cr': 'd'},
    unfold=True,
    kpath = [
    [r'\Gamma', r'K'],   # Γ → K
    [r'K',      r'M'],   # K → M
    [r'M',      r'\Gamma']  # M → Γ
],  # NotImplemented 3 slices
    high_symm_points=high_symmetry_points,
    n=n_kpoints_each_path,
    M=M,
    # output=os.path.join(band_folder, 'band_plain.png'),
    # scale_factor=5,
    interpolate=True
)
# Out:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:276: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:798: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:1365: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:

# %%
fig, ax = st.band_element_orbitals(
    folder= '/global/cfs/cdirs/m3578/chenbo/PdCrO2_calculation/band_unfold',  
    save=False,
    erange=[-4,3],
    figsize= (4, 2),      
    element_orbital_dict = {'Pd': [6]},  
    unfold=True,
    kpath = [
    [r'\Gamma', r'K'],   # Γ → K
    [r'K',      r'M'],   # K → M
    [r'M',      r'\Gamma']  # M → Γ
],  # NotImplemented 3 slices
    high_symm_points=high_symmetry_points,
    n=n_kpoints_each_path,
    M=M,
    # output=os.path.join(band_folder, 'band_plain.png'),
    # scale_factor=5,
    interpolate=True
)
# Out:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:276: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:798: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:1365: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:

# %%
fig, ax = st.band_element_orbitals(
    folder= '/global/cfs/cdirs/m3578/chenbo/PdCrO2_calculation/band_unfold',  
    save=False,
    erange=[-4,3],
    figsize= (4, 2),      
    element_orbital_dict = {'Pd': [4,5,6,7,8]},  
    unfold=True,
    kpath = [
    [r'\Gamma', r'K'],   # Γ → K
    [r'K',      r'M'],   # K → M
    [r'M',      r'\Gamma']  # M → Γ
],  # NotImplemented 3 slices
    high_symm_points=high_symmetry_points,
    n=n_kpoints_each_path,
    M=M,
    # output=os.path.join(band_folder, 'band_plain.png'),
    # scale_factor=5,
    interpolate=True
)
# Out:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:276: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:798: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
# /global/cfs/cdirs/m3578/chenbo/.conda/envs/ogre_debug/lib/python3.9/site-packages/pymatgen/io/vasp/inputs.py:1365: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, "rt") as f:
