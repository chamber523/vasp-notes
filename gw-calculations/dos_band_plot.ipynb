# %%
from vaspvis.workflow import plot_band_dos_and_inset
compare_data_array = [
    "/global/cfs/cdirs/m3578/zefeng/Heusler/Heusler_BO/corrected/Co2CrIn_GW_2D/PBE",
    "/global/cfs/cdirs/m3578/zefeng/Heusler/extra/Co2CrIn/HSE",
    "/global/cfs/cdirs/m3578/zefeng/Heusler/extra/Co2CrIn/GW",
    "/global/cfs/cdirs/m3578/zefeng/Heusler/Heusler_BO/corrected/Co2CrIn_GW_2D/PBE+U_2D"
]
compare_data_label_array = [
    "PBE",
    "HSE",
    "GW",
    "PBE+U"
]
is_gw_list = [
    False,
    False,
    True,
    False
]
band_folder_list = [
    "band_GXWKGL",
    "band_GXWKGL",
    "gw_band_SP",
    "band_GXWKGL"
]
element_spd_dict_main = {'Co': 'd', 'Cr': 'd', 'In': 'p'}
color_list_main = ['#D150FB', '#CD2B00', '#00BDFF']
output_folder = "Co2CrIn"
plot_band_dos_and_inset(
        compare_data_array,
        compare_data_label_array,
        is_gw_list,
        band_folder_list,
        element_spd_dict_main,
        color_list_main,
        output_folder,
        element_spd_dict_inset=None,
        color_list_inset=None,
        wannier_suffix="-bands",
        fill=True,
        alpha=0.3,
        linewidth=1.25,
        sigma=0.05,
        delta=0.0375,
        legend=False,
        erange=(-4, 4),
        fontsize=14,
        figsize_main=(6, 4),
        dos_figsize=(2, 4),
)

# %%
from vaspvis.workflow import plot_band_dos_and_inset
compare_data_array = [
    "/global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2NbSn"
]
compare_data_label_array = [
    "HSE"
]
is_gw_list = [
    False
]
band_folder_list = [
    "band_GXWKGL"
]
element_spd_dict_main = {'Co': 'd', 'Nb': 'd', 'Sn': 'p'}
color_list_main = ['#D150FB', '#CD2B00', '#00BDFF']
output_folder = "Co2NbSn"
plot_band_dos_and_inset(
        compare_data_array,
        compare_data_label_array,
        is_gw_list,
        band_folder_list,
        element_spd_dict_main,
        color_list_main,
        output_folder,
        element_spd_dict_inset=None,
        color_list_inset=None,
        wannier_suffix="-bands",
        fill=True,
        alpha=0.3,
        linewidth=1.25,
        sigma=0.05,
        delta=0.0375,
        legend=False,
        erange=(-4, 4),
        fontsize=14,
        figsize_main=(6, 4),
        dos_figsize=(2, 4),
)
# Out:
# Processing: HSE | Path: /global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2NbSn
# Processing: /global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2NbSn
# Magnetic moment: 3.203
# Spin Polarization (%): 100.0

# %%
from vaspvis.workflow import plot_band_dos_and_inset
compare_data_array = [
    "/global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2TiSn"
]
compare_data_label_array = [
    "HSE"
]
is_gw_list = [
    False
]
band_folder_list = [
    "band_GXWKGL"
]
element_spd_dict_main = {'Co': 'd', 'Ti': 'd', 'Sn': 'p'}
color_list_main = ['#D150FB', '#CD2B00', '#00BDFF']
output_folder = "Co2TiSn"
plot_band_dos_and_inset(
        compare_data_array,
        compare_data_label_array,
        is_gw_list,
        band_folder_list,
        element_spd_dict_main,
        color_list_main,
        output_folder,
        element_spd_dict_inset=None,
        color_list_inset=None,
        wannier_suffix="-bands",
        fill=True,
        alpha=0.3,
        linewidth=1.25,
        sigma=0.05,
        delta=0.0375,
        legend=False,
        erange=(-4, 4),
        fontsize=14,
        figsize_main=(6, 4),
        dos_figsize=(2, 4),
)
# Out:
# Processing: HSE | Path: /global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2TiSn
# Processing: /global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2TiSn
# Magnetic moment: 2.357
# Spin Polarization (%): 100.0

# %%
from vaspvis.workflow import plot_band_dos_and_inset
compare_data_array = [
    "/global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2ZrAl"
]
compare_data_label_array = [
    "HSE"
]
is_gw_list = [
    False
]
band_folder_list = [
    "band_GXWKGL"
]
element_spd_dict_main = {'Co': 'd', 'Zr': 'd', 'Al': 'p'}
color_list_main = ['#D150FB', '#CD2B00', '#00BDFF']
output_folder = "Co2ZrAl"
plot_band_dos_and_inset(
        compare_data_array,
        compare_data_label_array,
        is_gw_list,
        band_folder_list,
        element_spd_dict_main,
        color_list_main,
        output_folder,
        element_spd_dict_inset=None,
        color_list_inset=None,
        wannier_suffix="-bands",
        fill=True,
        alpha=0.3,
        linewidth=1.25,
        sigma=0.05,
        delta=0.0375,
        legend=False,
        erange=(-4, 4),
        fontsize=14,
        figsize_main=(6, 4),
        dos_figsize=(2, 4),
)
# Out:
# Processing: HSE | Path: /global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2ZrAl
# Processing: /global/cfs/cdirs/m3578/chenbo/Heuslers/HSE/Co2ZrAl
# Magnetic moment: 1.885
# Spin Polarization (%): -32.802311435338964
